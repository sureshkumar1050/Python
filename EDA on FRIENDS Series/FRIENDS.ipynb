# %%
import pandas as pd

# %%
df = pd.read_csv('E:\\Python\\Friends\\friends_episodes_v2.csv')

# %%
df
# Out:
#      Year_of_prod  Season                                   Episode_Title  \
# 0            1994       1            The One with the Sonogram at the End
# 1            1994       1                          The One with the Thumb
# 2            1994       1              The One with George Stephanopoulos
# 3            1994       1  The One with the East German Laundry Detergent
# 4            1994       1                           The One with the Butt
# ..            ...     ...                                             ...
# 230          2004      10                  The One with Princess Consuela
# 231          2004      10                      The One Where Estelle Dies
# 232          2004      10          The One with Rachel's Going Away Party
# 233          2004      10                                    The Last One
# 234          2004      10                                    The Last One
#
#      Duration                                            Summary  \
# ...

# %%
df.head(5)
# Out:
#    Year_of_prod  Season                                   Episode_Title  \
# 0          1994       1            The One with the Sonogram at the End
# 1          1994       1                          The One with the Thumb
# 2          1994       1              The One with George Stephanopoulos
# 3          1994       1  The One with the East German Laundry Detergent
# 4          1994       1                           The One with the Butt
#
#    Duration                                            Summary  \
# 0        22  Ross finds out his ex-wife is pregnant. Rachel...
# 1        22  Monica becomes irritated when everyone likes h...
# 2        22  Joey and Chandler take Ross to a hockey game t...
# 3        22  Eager to spend time with Rachel, Ross pretends...
# 4        22  Monica's obsessiveness is put to the test afte...
#
#          Director  Stars  Votes
# 0   James Burrows    8.1   4888
# 1   James Burrows    8.2   4605
# 2   James Burrows    8.1   4468
# ...

# %%
df.tail(5)
# Out:
#      Year_of_prod  Season                           Episode_Title  Duration  \
# 230          2004      10          The One with Princess Consuela        22
# 231          2004      10              The One Where Estelle Dies        22
# 232          2004      10  The One with Rachel's Going Away Party        22
# 233          2004      10                            The Last One        30
# 234          2004      10                            The Last One        30
#
#                                                Summary        Director  Stars  \
# 230  When Phoebe goes to get her name changed she r...  Gary Halvorson    8.6
# 231  Ross tries to get Rachel to go back to Ralph L...  Gary Halvorson    8.5
# 232  The gang throws Rachel a goodbye party, during...  Gary Halvorson    8.9
# 233  Erica gives birth to the baby that Monica and ...    Kevin Bright    9.5
# 234  Phoebe races Ross to the airport in a bid to s...    Kevin Bright    9.7
#
#      Votes
# 230   2989
# 231   2771
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 235 entries, 0 to 234
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Year_of_prod   235 non-null    int64
#  1   Season         235 non-null    int64
#  2   Episode_Title  235 non-null    object
#  3   Duration       235 non-null    int64
#  4   Summary        235 non-null    object
#  5   Director       235 non-null    object
#  6   Stars          235 non-null    float64
#  7   Votes          235 non-null    int64
# dtypes: float64(1), int64(4), object(3)
# memory usage: 14.8+ KB

# %%
df.shape
# Out:
# (235, 8)

# %%
df.describe()
# Out:
#        Year_of_prod      Season    Duration       Stars         Votes
# count    235.000000  235.000000  235.000000  235.000000    235.000000
# mean    1998.982979    5.395745   22.340426    8.459574   3352.285106
# std        2.831396    2.805821    1.517372    0.397029    824.214570
# min     1994.000000    1.000000   22.000000    7.200000   2557.000000
# 25%     1997.000000    3.000000   22.000000    8.200000   2885.500000
# 50%     1999.000000    5.000000   22.000000    8.400000   3147.000000
# 75%     2001.000000    8.000000   22.000000    8.700000   3579.500000
# max     2004.000000   10.000000   30.000000    9.700000  10381.000000

# %%
df['Duration'].mean()
# Out:
# 22.340425531914892

# %%
df['Duration'].mode()
# Out:
# 0    22
# Name: Duration, dtype: int64

# %%
df['Duration'].median()
# Out:
# 22.0

# %%
df['Stars'].mean()
# Out:
# 8.459574468085107

# %%
df['Stars'].mode()
# Out:
# 0    8.2
# Name: Stars, dtype: float64

# %%
df['Votes'].mean()
# Out:
# 3352.285106382979

# %%
df['Season'].median()
# Out:
# 5.0

# %%
df['Year_of_prod'].min()
# Out:
# 1994

# %%
df['Year_of_prod'].max()
# Out:
# 2004

# %%
df['Season'].value_counts()
# Out:
# Season
# 3     25
# 6     25
# 2     24
# 4     24
# 5     24
# 7     24
# 8     24
# 9     24
# 1     23
# 10    18
# Name: count, dtype: int64

# %%
df['Year_of_prod'].value_counts().sort_index()
# Out:
# Year_of_prod
# 1994     9
# 1995    23
# 1996    25
# 1997    25
# 1998    24
# 1999    24
# 2000    25
# 2001    25
# 2002    23
# 2003    22
# 2004    10
# Name: count, dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.countplot(x=df['Season'],data=df,palette='seismic')
plt.title('Episode Count According to Season')
plt.xlabel('Season')
plt.ylabel('Episode')
plt.grid()

# %%
df.groupby('Season')['Duration'].sum()
# Out:
# Season
# 1     506
# 2     528
# 3     550
# 4     544
# 5     528
# 6     582
# 7     528
# 8     528
# 9     544
# 10    412
# Name: Duration, dtype: int64

# %%
Season_duration = df.groupby('Season')['Duration'].mean().reset_index()
Season_duration
# Out:
#    Season   Duration
# 0       1  22.000000
# 1       2  22.000000
# 2       3  22.000000
# 3       4  22.666667
# 4       5  22.000000
# 5       6  23.280000
# 6       7  22.000000
# 7       8  22.000000
# 8       9  22.666667
# 9      10  22.888889

# %%
Season_Star = df.groupby('Season')['Stars'].mean().reset_index()
Season_Star
# Out:
#    Season     Stars
# 0       1  8.317391
# 1       2  8.458333
# 2       3  8.408000
# 3       4  8.475000
# 4       5  8.637500
# 5       6  8.496000
# 6       7  8.437500
# 7       8  8.445833
# 8       9  8.291667
# 9      10  8.677778

# %%
df.groupby('Season')['Votes'].sum()
# Out:
# Season
# 1     95397
# 2     89014
# 3     86462
# 4     81441
# 5     82942
# 6     78827
# 7     70577
# 8     71609
# 9     66254
# 10    65264
# Name: Votes, dtype: int64

# %%
df.groupby('Season')['Votes'].mean()
# Out:
# Season
# 1     4147.695652
# 2     3708.916667
# 3     3458.480000
# 4     3393.375000
# 5     3455.916667
# 6     3153.080000
# 7     2940.708333
# 8     2983.708333
# 9     2760.583333
# 10    3625.777778
# Name: Votes, dtype: float64

# %%
sns.barplot(x=Season_duration['Season'],y=Season_duration['Duration'])
plt.title('Duration of Different Season')
plt.xlabel('Season')
plt.ylabel('Total Duration')
# Out:
# Text(0, 0.5, 'Total Duration')

# %%
df.loc[12:15]
# Out:
#     Year_of_prod  Season                   Episode_Title  Duration  \
# 12          1995       1   The One with the Candy Hearts        22
# 13          1995       1     The One with the Stoned Guy        22
# 14          1995       1  The One with Two Parts: Part 1        22
# 15          1995       1  The One with Two Parts: Part 2        22
#
#                                               Summary         Director  Stars  \
# 12  As Valentine's Day approaches; Ross and his da...    James Burrows    8.3
# 13  Monica cooks a gourmet meal for a restaurateur...     Alan Myerson    8.2
# 14  Phoebe feels neglected when Joey falls for her...  Michael Lembeck    8.2
# 15  Rachel switches identities with Monica so she ...  Michael Lembeck    8.5
#
#     Votes
# 12   3866
# 13   3915
# 14   3834
# 15   3883

# %%
df.loc[(df['Stars'])>9]
# Out:
#      Year_of_prod  Season                                      Episode_Title  \
# 36           1996       2                        The One with the Prom Video
# 52           1996       3                         The One with the Flashback
# 62           1997       3                     The One with the Morning After
# 72           1997       4                         The One with the Jellyfish
# 79           1997       4                     The One with Chandler in a Box
# 83           1998       4                           The One with the Embryos
# 95           1998       4                        The One with Ross's Wedding
# 103          1998       5                 The One with All the Thanksgivings
# 104          1998       5                       The One with Ross's Sandwich
# 106          1999       5                   The One with All the Resolutions
# 109          1999       5                  The One Where Everybody Finds Out
# ...

# %%
df.loc[(df['Duration'])>29]
# Out:
#      Year_of_prod  Season                 Episode_Title  Duration  \
# 94           1998       4   The One with Ross's Wedding        30
# 95           1998       4   The One with Ross's Wedding        30
# 134          2000       6  The One That Could Have Been        30
# 135          2000       6  The One That Could Have Been        30
# 143          2000       6     The One with the Proposal        30
# 144          2000       6     The One with the Proposal        30
# 233          2004      10                  The Last One        30
# 234          2004      10                  The Last One        30
#
#                                                Summary         Director  \
# 94   Phoebe tries to help Rachel deal with her feel...     Kevin Bright
# 95   Phoebe tries to warn the gang that Rachel is c...     Kevin Bright
# 134  When Rachel hears Barry and Mindy are getting ...  Michael Lembeck
# 135  The gang continue to think about how different...  Michael Lembeck
# ...

# %%
plt.figure(figsize=(10,5))
sns.lineplot(x=Season_Star['Season'],y=Season_Star['Stars'],marker='o')
plt.xlabel('Season')
plt.ylabel('Stars')
plt.show()
# Out:
# C:\Users\User\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\User\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
Director_star = df.groupby('Director')['Stars'].mean().reset_index()
Director_star
# Out:
#                 Director     Stars
# 0           Alan Myerson  8.450000
# 1            Andrew Tsao  8.600000
# 2         Arlene Sanford  8.100000
# 3              Ben Weiss  8.300000
# 4   Dana De Vally Piazza  8.400000
# 5        David Schwimmer  8.540000
# 6        David Steinberg  8.500000
# 7       Ellen Gittelsohn  8.300000
# 8           Gail Mancuso  8.357143
# 9         Gary Halvorson  8.401852
# 10         James Burrows  8.514286
# 11         Joe Regalbuto  9.100000
# 12          Kevin Bright  8.646296
# 13        Mary Kay Place  8.500000
# 14       Michael Lembeck  8.520833
# 15         Pamela Fryman  8.700000
# 16          Paul Lazarus  8.200000
# 17          Peter Bonerz  8.325000
# 18          Robby Benson  8.183333
# 19    Roger Christiansen  8.200000
# 20             Sam Simon  8.300000
# 21          Sheldon Epps  8.466667
# 22        Shelley Jensen  8.433333
# 23         Stephen Prime  8.400000
# 24       Steve Zuckerman  8.100000
# 25          Terry Hughes  8.220000
# ...

# %%
Highest_director = df.groupby('Director')['Stars'].max().reset_index()
Highest_director
# Out:
#                 Director  Stars
# 0           Alan Myerson    8.7
# 1            Andrew Tsao    8.6
# 2         Arlene Sanford    8.1
# 3              Ben Weiss    8.8
# 4   Dana De Vally Piazza    8.8
# 5        David Schwimmer    9.1
# 6        David Steinberg    8.5
# 7       Ellen Gittelsohn    8.3
# 8           Gail Mancuso    9.0
# 9         Gary Halvorson    9.3
# 10         James Burrows    9.4
# 11         Joe Regalbuto    9.1
# 12          Kevin Bright    9.7
# 13        Mary Kay Place    8.5
# 14       Michael Lembeck    9.7
# 15         Pamela Fryman    8.9
# 16          Paul Lazarus    8.2
# 17          Peter Bonerz    9.1
# 18          Robby Benson    8.4
# 19    Roger Christiansen    8.2
# 20             Sam Simon    8.3
# 21          Sheldon Epps    8.7
# 22        Shelley Jensen    9.1
# 23         Stephen Prime    8.4
# 24       Steve Zuckerman    8.1
# 25          Terry Hughes    8.6
# 26       Thomas Schlamme    8.1
# 27          Todd Holland    8.0

# %%
plt.figure(figsize=(50,30))
sns.lineplot(x=Highest_director['Director'],y=Highest_director['Stars'],marker='o')
plt.xlabel('Director')
plt.ylabel('Stars')
plt.show()
# Out:
# C:\Users\User\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\User\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
Lowest_Director = df.groupby('Director')['Stars'].min().reset_index()
Lowest_Director
# Out:
#                 Director  Stars
# 0           Alan Myerson    8.2
# 1            Andrew Tsao    8.6
# 2         Arlene Sanford    8.1
# 3              Ben Weiss    7.8
# 4   Dana De Vally Piazza    8.2
# 5        David Schwimmer    8.1
# 6        David Steinberg    8.5
# 7       Ellen Gittelsohn    8.3
# 8           Gail Mancuso    7.9
# 9         Gary Halvorson    7.5
# 10         James Burrows    8.1
# 11         Joe Regalbuto    9.1
# 12          Kevin Bright    7.4
# 13        Mary Kay Place    8.5
# 14       Michael Lembeck    8.1
# 15         Pamela Fryman    8.5
# 16          Paul Lazarus    8.2
# 17          Peter Bonerz    7.2
# 18          Robby Benson    7.9
# 19    Roger Christiansen    8.2
# 20             Sam Simon    8.3
# 21          Sheldon Epps    8.2
# 22        Shelley Jensen    8.1
# 23         Stephen Prime    8.4
# 24       Steve Zuckerman    8.1
# 25          Terry Hughes    8.1
# 26       Thomas Schlamme    8.0
# 27          Todd Holland    8.0

# %%
plt.figure(figsize=(50,30))
sns.lineplot(x=Lowest_Director['Director'],y=Lowest_Director['Stars'],marker='o')
plt.xlabel('Director')
plt.ylabel('Stars')
plt.show()
# Out:
# C:\Users\User\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\User\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
